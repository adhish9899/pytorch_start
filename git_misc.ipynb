# %% [markdown]
# ## MOUNT YOUR GOOGLE DRIVE BEFORE PROCEEDING

# %%
import os
os.chdir("drive/My Drive/PyTorch/pytorch_start")

# %%
# !git status
# !git config --global user.name "adhish9899"
# !git config --global user.email "aggarwaladhish@ymail.com"
# !git config --global user.password "Divyanshi!23"
# !git add .; git commit -m "commit"; git push origin master
