# %% [markdown]
# ## MAKE SURE TO MOUNT THE DRIVE BEFORE MOVING FORWARD

# %%
import os
os.chdir("/content/drive/My Drive/PyTorch/pytorch_start")

# %%
# !git remote set-url origin https://adhish9899:c8d876deff40709b0992fe987e4dd9f4bb2ef2e7@github.com/adhish9899/pytorch_start.git

# %% [markdown]
# ### CHECK THE FILES YOU WANT TO ADD AND COMMIT

# %%
# !git status

# %%
# !ls
# !git add -A
# Out:
# ch_2.ipynb  ch_4.ipynb	ch_6.ipynb  ch_8.ipynb	     data
# ch_3.ipynb  ch_5.ipynb	ch_7.ipynb  colab_git.ipynb  old_code

# %% [markdown]
# ### COMMITING THE CODE

# %%
# !git config --global user.email "aggarwaladhish@ymail.com"
# !git config --global user.name "adhish9899"

# !git commit -m "completed chapter 8"
# Out:
# [master 47c3f17] completed chapter 8
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 ch_8.ipynb
#  rewrite colab_git.ipynb (80%)

# %% [markdown]
# ### PUSHING THE CODE

# %%
# !git remote set-url origin https://adhish9899:5e862ed2f4d85ff691d9d184609cb76f03fee4a4@github.com/adhish9899/pytorch_start.git

# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 16.95 KiB | 3.39 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/adhish9899/pytorch_start.git
#    31a0006..47c3f17  master -> master

# %% [markdown]
# ## CREATING A .GITIGNORE FILE & APPENING DATA TO IT

# %%
# !pwd
# Out:
# /content/drive/My Drive/PyTorch/pytorch_start

# %%
# !touch .gitignore

# %%
# !echo "**/data" >> .gitignore

# %%
# !cat .gitignore
# Out:
# **/data
