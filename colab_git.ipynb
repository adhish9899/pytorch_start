# %% [markdown]
# ## MAKE SURE TO MOUNT THE DRIVE BEFORE MOVING FORWARD

# %%
import os
os.chdir("/content/drive/My Drive/PyTorch/pytorch_start")

# %%
# !git remote set-url origin https://adhish9899:c8d876deff40709b0992fe987e4dd9f4bb2ef2e7@github.com/adhish9899/pytorch_start.git

# %% [markdown]
# ### CHECK THE FILES YOU WANT TO ADD AND COMMIT

# %%
# !git status

# %%
# !ls
# !git add -A
# Out:
# ch_2.ipynb  ch_3.ipynb	ch_4.ipynb  ch_5.ipynb	colab_git.ipynb  data  old_code

# %% [markdown]
# ### COMMITING THE CODE

# %%
# !git config --global user.email "aggarwaladhish@ymail.com"
# !git config --global user.name "adhish9899"

# !git commit -m "completed chapter 4 and adding chapter 5"
# Out:
# [master ee32565] completed chapter 4 and adding chapter 5
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite ch_4.ipynb (97%)
#  create mode 100644 ch_5.ipynb
#  rewrite colab_git.ipynb (83%)

# %% [markdown]
# ### PUSHING THE CODE

# %%
# !git remote set-url origin https://adhish9899:c8d876deff40709b0992fe987e4dd9f4bb2ef2e7@github.com/adhish9899/pytorch_start.git

# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 4.20 KiB | 537.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/adhish9899/pytorch_start.git
#    36f31ae..ee32565  master -> master

# %% [markdown]
# ## CREATING A .GITIGNORE FILE & APPENING DATA TO IT

# %%
# !pwd
# Out:
# /content/drive/My Drive/PyTorch/pytorch_start

# %%
# !touch .gitignore

# %%
# !echo "**/data" >> .gitignore

# %%
# !cat .gitignore
# Out:
# **/data
